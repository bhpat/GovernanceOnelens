# %% [markdown]
# # fabric-inventory notebook — DEPRECATED (superseded)
#
# This interactive notebook has been **retired**. The scheduled scan now runs as a
# **Fabric Spark Job Definition** for a more robust, source-controlled, unattended runtime.
#
# ## Where the scan lives now
#
# | Purpose | Artifact |
# | --- | --- |
# | **Production (nightly)** | Spark Job Definition `governance-onelens-scan` — source: [`scanner/sjd_governance_scan.py`](./sjd_governance_scan.py). Scheduled daily 02:00 UTC. |
# | **Local dev / on-demand** | [`scanner/fabric_inventory.py`](./fabric_inventory.py) (inventory + enrichment + lineage) then [`scanner/derive_metrics.py`](./derive_metrics.py) (coverage + posture). |
#
# The SJD entrypoint is self-contained and does the **full** pipeline in one pass
# (inventory → owner/tags → Power BI enrichment → lineage → metric derivation) writing all
# six tables via Spark JDBC. Edit the `.py` files above — not this notebook.
#
# > The old scheduled Notebook item in Fabric is retained as a fallback with its schedule **disabled**.
